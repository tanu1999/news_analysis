# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_json("News_Category_Dataset_v3.json", lines=True)
df
# Out:
#                                                      link
# 0       https://www.huffpost.com/entry/covid-boosters-...  \
# 1       https://www.huffpost.com/entry/american-airlin...
# 2       https://www.huffpost.com/entry/funniest-tweets...
# 3       https://www.huffpost.com/entry/funniest-parent...
# 4       https://www.huffpost.com/entry/amy-cooper-lose...
# ...                                                   ...
# 209522  https://www.huffingtonpost.com/entry/rim-ceo-t...
# 209523  https://www.huffingtonpost.com/entry/maria-sha...
# 209524  https://www.huffingtonpost.com/entry/super-bow...
# 209525  https://www.huffingtonpost.com/entry/aldon-smi...
# 209526  https://www.huffingtonpost.com/entry/dwight-ho...
#
#                                                  headline   category
# 0       Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS  \
# 1       American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209527 entries, 0 to 209526
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   link               209527 non-null  object
#  1   headline           209527 non-null  object
#  2   category           209527 non-null  object
#  3   short_description  209527 non-null  object
#  4   authors            209527 non-null  object
#  5   date               209527 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 9.6+ MB

# %%
df['category'].value_counts()
# Out:
# category
# POLITICS          35602
# WELLNESS          17945
# ENTERTAINMENT     17362
# TRAVEL             9900
# STYLE & BEAUTY     9814
# PARENTING          8791
# HEALTHY LIVING     6694
# QUEER VOICES       6347
# FOOD & DRINK       6340
# BUSINESS           5992
# COMEDY             5400
# SPORTS             5077
# BLACK VOICES       4583
# HOME & LIVING      4320
# PARENTS            3955
# THE WORLDPOST      3664
# WEDDINGS           3653
# WOMEN              3572
# CRIME              3562
# IMPACT             3484
# DIVORCE            3426
# WORLD NEWS         3299
# MEDIA              2944
# WEIRD NEWS         2777
# GREEN              2622
# WORLDPOST          2579
# RELIGION           2577
# STYLE              2254
# SCIENCE            2206
# TECH               2104
# TASTE              2096
# MONEY              1756
# ARTS               1509
# ENVIRONMENT        1444
# FIFTY              1401
# GOOD NEWS          1398
# U.S. NEWS          1377
# ARTS & CULTURE     1339
# ...

# %%
df['category'].value_counts().plot.bar(figsize=(20, 10));

# %%
df['date'].hist(bins=100, figsize=(20, 10));

# %%
df['authors'].value_counts(ascending=False).reset_index()
# Out:
#                                                  authors  count
# 0                                                         37418
# 1                                              Lee Moran   2954
# 2                                             Ron Dicker   2219
# 3                                               Ed Mazza   1590
# 4                                         Mary Papenfuss   1566
# ...                                                  ...    ...
# 29164                      Holly Ramer, Associated Press      1
# 29165                    Gina Carey, The Huffington Post      1
# 29166                    Randall Chase, Associated Press      1
# 29167                             Stephen Ohlemacher, AP      1
# 29168  John Giacobbi, Contributor\nTales from the Int...      1
#
# [29169 rows x 2 columns]

# %%
from wordcloud import WordCloud

def make_wordcloud(text):
    wordcloud = WordCloud(width=1000, height=1000).generate(text)
    plt.figure(figsize = (10,10))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()

# %%
txt = str(df['headline'].values).lower()
make_wordcloud(txt)

# %%
txt = str(df['short_description'].values).lower()
make_wordcloud(txt)
